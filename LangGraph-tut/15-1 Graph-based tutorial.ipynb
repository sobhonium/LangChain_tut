# %%
# May 2025
# transforming documents into graph-based representations using a large language model (LLM)

# %% [raw]
# NetworkX library is a powerful Python package for creating, manipulating, and analyzing graphs and networks.
#
# DiGraph stands for Directed Graph.

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph()
G.add_edges_from([
    ("A", "B"),
    ("B", "C"),
    ("C", "D"),
    ("D", "A"),
    ("A", "C", {"weight": 3}),
])

print("Nodes:", G.nodes)
print("Edges:", G.edges)
print("Weights:", nx.get_edge_attributes(G, 'weight'))
# Out:
# Nodes: ['A', 'B', 'C', 'D']
# Edges: [('A', 'B'), ('A', 'C'), ('B', 'C'), ('C', 'D'), ('D', 'A')]
# Weights: {('A', 'C'): 3}

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph()
G.add_edges_from([
    ("A", "B", {"weight": 1}),
    ("B", "C", {"weight": 2}),
    ("C", "D", {"weight": 3}),
    ("D", "A", {"weight": 4}),
    ("A", "C", {"weight": 3}),
])

print("Nodes:", G.nodes)
print("Edges:", G.edges)
print("Weights:", nx.get_edge_attributes(G, 'weight'))
# Out:
# Nodes: ['A', 'B', 'C', 'D']
# Edges: [('A', 'B'), ('A', 'C'), ('B', 'C'), ('C', 'D'), ('D', 'A')]
# Weights: {('A', 'B'): 1, ('A', 'C'): 3, ('B', 'C'): 2, ('C', 'D'): 3, ('D', 'A'): 4}

# %% [markdown]
# ## Visualization

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph()
G.add_edges_from([
    ("A", "B"),
    ("B", "C"),
    ("C", "D"),
    ("D", "A"),
    ("A", "C", {"weight": 3}),
])

print("Nodes:", G.nodes)
print("Edges:", G.edges)

# Analysis
if not nx.is_directed_acyclic_graph(G):
    print("Graph has a cycle.")

# Visualization
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color="lightgreen", arrows=True)
nx.draw_networkx_edge_labels(G, pos, edge_labels=nx.get_edge_attributes(G, "weight"))
plt.title("Directed Graph")
plt.show()
# Out:
# Nodes: ['A', 'B', 'C', 'D']
# Edges: [('A', 'B'), ('A', 'C'), ('B', 'C'), ('C', 'D'), ('D', 'A')]
# Graph has a cycle.

# %%
import matplotlib.pyplot as plt

pos = nx.spring_layout(G)  # Layout algorithm for nice spacing
nx.draw(G, pos, with_labels=True, node_color='lightblue', arrows=True)
nx.draw_networkx_edge_labels(G, pos, edge_labels=nx.get_edge_attributes(G, 'weight'))
plt.show()

# %% [markdown]
# ## PageRand

# %% [raw]
# What is PageRank?
#
# PageRank is an algorithm originally developed by Google to rank web pages by importance, based on incoming links.
#
# In a graph:
#
# A node is important if many important nodes link to it.
# It works on directed graphs.

# %%
G = nx.DiGraph()

# Create edges (A → B means A links to B)
edges = [
    ("A", "B"),
    ("A", "C"),
    ("B", "C"),
    ("C", "A"),
    ("D", "C"),
]

G.add_edges_from(edges)

# %%
pagerank_scores = nx.pagerank(G, alpha=0.85)  # alpha is the damping factor (default 0.85)

# Print scores
for node, score in pagerank_scores.items():
    print(f"{node}: {score:.4f}")
# Out:
# A: 0.3725
# B: 0.1958
# C: 0.3942
# D: 0.0375

# %%
pos = nx.spring_layout(G)
node_sizes = [pagerank_scores[n] * 3000 for n in G.nodes]  # scale for visibility

nx.draw(G, pos, with_labels=True, node_size=node_sizes, node_color='skyblue', arrows=True)
plt.title("PageRank Node Sizes")
plt.show()
